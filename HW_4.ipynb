# %% [markdown]
# ## Задача 1
#
# О непрерывной равномерно распределенной случайной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %% [markdown]
# $$D(X) = \dfrac{(b - a)^2}{12}=0.2$$
#
# $$a=0.5$$

# %%
# Правая граница найдем из определения диспресии

import pandas as pd
import numpy as np
from scipy import stats
from scipy import integrate
from matplotlib import pyplot as plt

a=0.5
ba=0.2*12
sqrt_ba=np.sqrt(ba)
b=sqrt_ba+a
print("Правая граница: ", b)
# Out:
# Правая граница:  2.049193338482967

# %% [markdown]
# $$M(X) = \dfrac{a + b}{2}$$

# %%
m=(a+b)/2
print(m)
# Out:
# 1.2745966692414834

# %% [markdown]
# ## Задача 2
#
# Рост взрослого населения города X имеет нормальное распределение, причем, средний рост равен 174 см, а среднее квадратическое отклонение равно 8 см. посчитайте, какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# 1. больше 182 см?
# 2. больше 190 см?
# 3. от 166 см до 190 см?
# 4. от 166 см до 182 см?
# 5. от 158 см до 190 см?
# 6. не выше 150 см или не ниже 190 см?
# 7. не выше 150 см или не ниже 198 см?
# 8. ниже 166 см?
#
# Задачу можно решить двумя способами: без использования сторонних библиотек (numpy, scipy, pandas и пр.), а затем проверить себя с помощью встроенных функций

# %%
loc=174
scale=8

samples = np.random.normal(loc, scale, size=10000)

print(samples)
# Out:
# [172.91980367 174.43516019 175.73224496 ... 159.58813665 168.6922335
#  168.62278369]

# %%
def edf(samples, x):
    return samples[samples < x].shape[0] / samples.shape[0]

ox = np.linspace(150, 200, 1000)
oy = np.array([edf(samples, x) for x in ox])

plt.plot(ox, oy)

# %%
def pdf_normal(loc, scale, x):
    return np.exp(- ((x - loc) ** 2) / (2 * scale ** 2)) / (scale * np.sqrt(2 * np.pi))

# %%
oy = np.array([pdf_normal(loc, scale, x) for x in ox])

plt.hist(samples, density=True, bins=15)
plt.plot(ox, oy)

# %%
oy = np.array([stats.norm.pdf(x, loc, scale) for x in ox])

plt.hist(samples, density=True, bins=15)
plt.plot(ox, oy)

# %%
def e(x):
    return exp(-t**2/2)

v = integrate.quad(e(182), 174, 2)


        

F=1/sqrt(2*pi)*v
# Out:
#   File "<ipython-input-4-03862de86fb9>", line 5
#     print v
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(v)?

# %% [markdown]
# ### Не успел доделать задачу №2
# Планирую достдать
